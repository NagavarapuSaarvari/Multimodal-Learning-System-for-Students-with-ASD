# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras import layers, models
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import itertools
import cv2
import random

data_dir = "Autism Facial Recognition Dataset"
train_dir = os.path.join(data_dir, "train")
test_dir = os.path.join(data_dir, "test")

img_size = (96, 96)
batch_size = 32
epochs = 70


train_ds = image_dataset_from_directory(
    train_dir,
    labels='inferred',
    label_mode='int',
    image_size=img_size,
    batch_size=batch_size,
    validation_split=0.2,
    subset='training',
    seed=123
)

val_ds = image_dataset_from_directory(
    train_dir,
    labels='inferred',
    label_mode='int',
    image_size=img_size,
    batch_size=batch_size,
    validation_split=0.2,
    subset='validation',
    seed=123
)

test_ds = image_dataset_from_directory(
    test_dir,
    labels='inferred',
    label_mode='int',
    image_size=img_size,
    batch_size=batch_size,
    seed=123
)

class_names = train_ds.class_names
num_classes = len(class_names)
print("Detected classes:", class_names)


labels_list = []
for _, y in train_ds.unbatch():
    labels_list.append(int(y))
class_weights = compute_class_weight('balanced', classes=np.unique(labels_list), y=labels_list)
class_weights = dict(enumerate(class_weights))
print("Class weights:", class_weights)

base_model = tf.keras.applications.MobileNetV2(
    input_shape=(img_size[0], img_size[1], 3),
    include_top=False,
    weights='imagenet'
)
base_model.trainable = False

inputs = layers.Input(shape=(img_size[0], img_size[1], 3))
x = preprocess_input(inputs)
x = base_model(x, training=False)

x = layers.Conv2D(128, (3, 3), activation='relu', padding="same")(x)
x = layers.BatchNormalization()(x)

x = layers.Conv2D(256, (3, 3), activation='relu', padding="same")(x)
x = layers.BatchNormalization()(x)

x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(256, activation='relu')(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(128, activation='relu')(x)
x = layers.Dropout(0.3)(x)

outputs = layers.Dense(num_classes, activation='softmax')(x)

model = models.Model(inputs, outputs)

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs,
    class_weight=class_weights
)

y_true = []
y_pred = []

for images, labels in test_ds:
    preds = model.predict(images)
    y_true.extend(labels.numpy())
    y_pred.extend(np.argmax(preds, axis=1))

print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=class_names))

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8,8))
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.colorbar()
tick_marks = np.arange(num_classes)
plt.xticks(tick_marks, class_names, rotation=45)
plt.yticks(tick_marks, class_names)
thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i,j], horizontalalignment="center",
             color="white" if cm[i,j] > thresh else "black")
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.tight_layout()
plt.show()

model.save("emotion_mobilenetv2.h5")
print("Model saved as emotion_mobilenetv2.h5")

all_images = []
all_labels = []

for idx, emotion in enumerate(class_names):
    folder = os.path.join(test_dir, emotion)
    files = [os.path.join(folder, f) for f in os.listdir(folder) if f.endswith(('.png','.jpg','.jpeg'))]
    all_images.extend(files)
    all_labels.extend([emotion]*len(files))
# Out:
# Found 6070 files belonging to 6 classes.
# Using 4856 files for training.
# Found 6070 files belonging to 6 classes.
# Using 1214 files for validation.
# Found 1530 files belonging to 6 classes.
# Detected classes: ['Natural', 'anger', 'fear', 'joy', 'sadness', 'surprise']
# Class weights: {0: 2.610752688172043, 1: 1.8146487294469358, 2: 3.928802588996764, 3: 0.36489329726480313, 4: 0.6293416277864178, 5: 2.0752136752136754}
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_10 (InputLayer)       [(None, 96, 96, 3)]       0
#
#  tf.math.truediv_1 (TFOpLamb  (None, 96, 96, 3)        0
#  da)
#
#  tf.math.subtract_1 (TFOpLam  (None, 96, 96, 3)        0
#  bda)
#
#  mobilenetv2_1.00_96 (Functi  (None, 3, 3, 1280)       2257984
#  onal)
#
#  conv2d_4 (Conv2D)           (None, 3, 3, 128)         1474688
#
#  batch_normalization_6 (Batc  (None, 3, 3, 128)        512
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 3, 3, 256)         295168
#
#  batch_normalization_7 (Batc  (None, 3, 3, 256)        1024
#  hNormalization)
#
#  global_average_pooling2d_3   (None, 256)              0
#  (GlobalAveragePooling2D)
#
#  dense_8 (Dense)             (None, 256)               65792
#
#  dropout_8 (Dropout)         (None, 256)               0
#
#  dense_9 (Dense)             (None, 128)               32896
#
#  dropout_9 (Dropout)         (None, 128)               0
#
#  dense_10 (Dense)            (None, 6)                 774
#
# =================================================================
# Total params: 4,128,838
# Trainable params: 1,870,086
# Non-trainable params: 2,258,752
# _________________________________________________________________
# Epoch 1/70
# 152/152 [==============================] - 8s 29ms/step - loss: 1.7126 - accuracy: 0.2558 - val_loss: 1.4376 - val_accuracy: 0.4102
# Epoch 2/70
# 152/152 [==============================] - 4s 24ms/step - loss: 1.2564 - accuracy: 0.4224 - val_loss: 1.1421 - val_accuracy: 0.5198
# Epoch 3/70
# 152/152 [==============================] - 4s 23ms/step - loss: 0.9857 - accuracy: 0.5387 - val_loss: 1.4533 - val_accuracy: 0.4440
# Epoch 4/70
# 152/152 [==============================] - 4s 24ms/step - loss: 0.8275 - accuracy: 0.6155 - val_loss: 1.2153 - val_accuracy: 0.5148
# Epoch 5/70
# 152/152 [==============================] - 4s 23ms/step - loss: 0.7136 - accuracy: 0.6827 - val_loss: 0.9804 - val_accuracy: 0.6038
# Epoch 6/70
# 152/152 [==============================] - 4s 23ms/step - loss: 0.6074 - accuracy: 0.7072 - val_loss: 1.3103 - val_accuracy: 0.5321
# Epoch 7/70
# 152/152 [==============================] - 4s 23ms/step - loss: 0.5184 - accuracy: 0.7426 - val_loss: 1.0110 - val_accuracy: 0.6351
# Epoch 8/70
# 152/152 [==============================] - 4s 23ms/step - loss: 0.4918 - accuracy: 0.7584 - val_loss: 0.8611 - val_accuracy: 0.6829
# Epoch 9/70
# 152/152 [==============================] - 4s 23ms/step - loss: 0.3999 - accuracy: 0.7992 - val_loss: 0.8541 - val_accuracy: 0.6952
# Epoch 10/70
# 152/152 [==============================] - 4s 23ms/step - loss: 0.3469 - accuracy: 0.8204 - val_loss: 1.0468 - val_accuracy: 0.6697
# Epoch 11/70
# 152/152 [==============================] - 4s 24ms/step - loss: 0.4052 - accuracy: 0.8072 - val_loss: 0.9216 - val_accuracy: 0.6829
# Epoch 12/70
# 152/152 [==============================] - 4s 23ms/step - loss: 0.3544 - accuracy: 0.8180 - val_loss: 0.9019 - val_accuracy: 0.7125
# Epoch 13/70
# 152/152 [==============================] - 4s 23ms/step - loss: 0.2847 - accuracy: 0.8503 - val_loss: 0.8545 - val_accuracy: 0.7306
# Epoch 14/70
# 152/152 [==============================] - 4s 23ms/step - loss: 0.3570 - accuracy: 0.8330 - val_loss: 0.9106 - val_accuracy: 0.7010
# Epoch 15/70
# 152/152 [==============================] - 4s 23ms/step - loss: 0.2571 - accuracy: 0.8565 - val_loss: 1.4509 - val_accuracy: 0.5939
# Epoch 16/70
# 152/152 [==============================] - 4s 24ms/step - loss: 0.2417 - accuracy: 0.8748 - val_loss: 0.8991 - val_accuracy: 0.7504
# Epoch 17/70
# 152/152 [==============================] - 4s 24ms/step - loss: 0.2564 - accuracy: 0.8764 - val_loss: 1.1369 - val_accuracy: 0.6458
# Epoch 18/70
# 152/152 [==============================] - 4s 24ms/step - loss: 0.2503 - accuracy: 0.8834 - val_loss: 1.0421 - val_accuracy: 0.6623
# Epoch 19/70
# 152/152 [==============================] - 4s 24ms/step - loss: 0.2926 - accuracy: 0.8694 - val_loss: 0.8274 - val_accuracy: 0.7488
# Epoch 20/70
# 152/152 [==============================] - 4s 23ms/step - loss: 0.2140 - accuracy: 0.8937 - val_loss: 1.0183 - val_accuracy: 0.7150
# Epoch 21/70
# 152/152 [==============================] - 4s 23ms/step - loss: 0.2362 - accuracy: 0.8972 - val_loss: 1.0491 - val_accuracy: 0.7035
# Epoch 22/70
# 152/152 [==============================] - 4s 23ms/step - loss: 0.2242 - accuracy: 0.8917 - val_loss: 1.0105 - val_accuracy: 0.7265
# Epoch 23/70
# 152/152 [==============================] - 4s 23ms/step - loss: 0
70
# 152/152 [==============================] - 4s 23ms/step - loss: 0.0615 - accuracy: 0.9747 - val_loss: 1.3639 - val_accuracy: 0.7603
# Epoch 54/70
# 152/152 [==============================] - 4s 23ms/step - loss: 0.0713 - accuracy: 0.9699 - val_loss: 1.4399 - val_accuracy: 0.7545
# Epoch 55/70
# 152/152 [==============================] - 4s 23ms/step - loss: 0.0680 - accuracy: 0.9753 - val_loss: 1.4208 - val_accuracy: 0.7405
# Epoch 56/70
# 152/152 [==============================] - 4s 23ms/step - loss: 0.1091 - accuracy: 0.9582 - val_loss: 1.2919 - val_accuracy: 0.7504
# Epoch 57/70
# 152/152 [==============================] - 4s 24ms/step - loss: 0.0558 - accuracy: 0.9759 - val_loss: 1.3344 - val_accuracy: 0.7718
# Epoch 58/70
# 152/152 [==============================] - 4s 23ms/step - loss: 0.0351 - accuracy: 0.9839 - val_loss: 1.4607 - val_accuracy: 0.7727
# Epoch 59/70
# 152/152 [==============================] - 4s 23ms/step - loss: 0.0308 - accuracy: 0.9874 - val_loss: 1.6820 - val_accuracy: 0.7669
# Epoch 60/70
# 152/152 [==============================] - 4s 23ms/step - loss: 0.0723 - accuracy: 0.9732 - val_loss: 2.5576 - val_accuracy: 0.6499
# Epoch 61/70
# 152/152 [==============================] - 4s 23ms/step - loss: 0.0783 - accuracy: 0.9673 - val_loss: 1.2986 - val_accuracy: 0.7479
# Epoch 62/70
# 152/152 [==============================] - 4s 23ms/step - loss: 0.0757 - accuracy: 0.9722 - val_loss: 1.3432 - val_accuracy: 0.7586
# Epoch 63/70
# 152/152 [==============================] - 4s 23ms/step - loss: 0.0622 - accuracy: 0.9802 - val_loss: 1.4597 - val_accuracy: 0.7438
# Epoch 64/70
# 152/152 [==============================] - 4s 23ms/step - loss: 0.0918 - accuracy: 0.9685 - val_loss: 1.8126 - val_accuracy: 0.6376
# Epoch 65/70
# 152/152 [==============================] - 4s 23ms/step - loss: 0.0902 - accuracy: 0.9650 - val_loss: 1.1954 - val_accuracy: 0.7372
# Epoch 66/70
# 152/152 [==============================] - 4s 24ms/step - loss: 0.0696 - accuracy: 0.9677 - val_loss: 1.3034 - val_accuracy: 0.7768
# Epoch 67/70
# 152/152 [==============================] - 4s 24ms/step - loss: 0.0795 - accuracy: 0.9730 - val_loss: 1.4368 - val_accuracy: 0.7455
# Epoch 68/70
# 152/152 [==============================] - 4s 24ms/step - loss: 0.1034 - accuracy: 0.9561 - val_loss: 1.2200 - val_accuracy: 0.7677
# Epoch 69/70
# 152/152 [==============================] - 4s 24ms/step - loss: 0.0691 - accuracy: 0.9732 - val_loss: 1.1992 - val_accuracy: 0.7644
# Epoch 70/70
# 152/152 [==============================] - 4s 24ms/step - loss: 0.0419 - accuracy: 0.9827 - val_loss: 1.3049 - val_accuracy: 0.7792
# 1/1 [==============================] - 1s 710ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 1s 1s/step
# Classification Report:
#               precision    recall  f1-score   support
#
#      Natural       0.09      0.05      0.06       140
#        anger       0.00      0.00      0.00        60
#         fear       0.10      0.01      0.02       700
#          joy       0.07      0.50      0.12       100
#      sadness       0.27      0.30      0.29       400
#     surprise       0.07      0.06      0.06       130
#
#     accuracy                           0.13      1530
#    macro avg       0.10      0.15      0.09      1530
# weighted avg       0.13      0.13      0.10      1530
# Model saved as emotion_mobilenetv2.h5

# %%
num_samples = 9
sample_indices = random.sample(range(len(all_images)), num_samples)
sample_images = [all_images[i] for i in sample_indices]
sample_labels = [all_labels[i] for i in sample_indices]

plt.figure(figsize=(12,12))
for i, img_path in enumerate(sample_images):
    img = cv2.imread(img_path)
    img_resized = cv2.resize(img, img_size)
    img_rgb = cv2.cvtColor(img_resized, cv2.COLOR_BGR2RGB)
    img_array = np.expand_dims(img_rgb, axis=0)

    preds = model.predict(img_array)
    pred_label = class_names[np.argmax(preds[0])]

    plt.subplot(3,3,i+1)
    plt.imshow(img_rgb)
    plt.title(f"True: {sample_labels[i]}\nPred: {pred_label}")
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
